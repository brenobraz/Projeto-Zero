# %%
import scipy as sp
import matplotlib.pyplot as plt
from ipywidgets import interact
# %matplotlib inline

# %%
wn = 2*2*sp.pi
wf = 2.1*2*sp.pi
f0 = 1
qsi = 0.15
wf = sp.linspace(0,20,1000)

# %%
def f(qsi):
    x = f0/((wn**2 - wf**2)**2 + (2*qsi*wn*wf)**2)
    plt.plot(wf,x)

# %%
interact(f,qsi=0.5)
